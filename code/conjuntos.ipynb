# %%
import matplotlib.pyplot as plt
from utils import *

efectividad = [12, 17, 25, 25]
altura = [170, 195, 220, 220]
sprint = [0, 0, 10, 15]
y = [0, 1, 1, 0]

# %%
plt.figure(figsize = (10, 5))
plt.plot(efectividad, y)
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(altura, y)
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(sprint, y)
plt.show()

# %% [markdown]
# ### Definición de reglas

# %%
r1 = ['Bascket-maker', 'Tall'    ]
r2 = ['Bascket-maker', 'Sprinter']
r3 = ['Tall',          'Sprinter']

# %%
import sys
sys.path.insert(1, '/model')

# %%
efectividad = [12, 17, 25, 25]
altura = [170, 195, 220, 220]
sprint = [0, 0, 10, 15]

Bascket_maker = Premise(efectividad)
Tall          = Premise(altura)
Sprinter      = Premise(sprint)

R1 = Rule((Bascket_maker, Tall),     0.80)
R2 = Rule((Bascket_maker, Sprinter), 0.95)
R3 = Rule((Tall,          Sprinter), 0.75)
